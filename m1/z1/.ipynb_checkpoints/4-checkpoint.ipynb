# %%
import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
import scipy.stats as stats
import plotly.express as px
from sklearn import preprocessing

# %%
df = pd.read_csv("DataSet1_4.csv", sep=',')
df = df.dropna()
df = df.reset_index(drop=True)
df["Day"] = df["Day"].astype("datetime64")
df["Year"] = df["Year"].astype("int")
df["Total confirmed cases of COVID-19"] = df["Total confirmed cases of COVID-19"].astype("int")
df
# Out:
#              Entity Code        Day  \
# 0       Afghanistan  AFG 2020-02-29
# 1       Afghanistan  AFG 2020-03-01
# 2       Afghanistan  AFG 2020-03-02
# 3       Afghanistan  AFG 2020-03-03
# 4       Afghanistan  AFG 2020-03-04
# ...             ...  ...        ...
# 162896     Zimbabwe  ZWE 2022-04-20
# 162897     Zimbabwe  ZWE 2022-04-21
# 162898     Zimbabwe  ZWE 2022-04-22
# 162899     Zimbabwe  ZWE 2022-04-23
# 162900     Zimbabwe  ZWE 2022-04-24
#
#         Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)  \
# 0                                                   0.833
# 1                                                   0.714
# 2                                                   0.000
# 3                                                   0.000
# 4                                                   0.000
# ...                                                   ...
# 162896                                             25.143
# ...

# %%
df.dtypes
# Out:
# Entity                                                                                      object
# Code                                                                                        object
# Day                                                                                 datetime64[ns]
# Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)           float64
# Total confirmed cases of COVID-19                                                            int32
# Year                                                                                         int32
# Continent                                                                                   object
# dtype: object

# %%
df.nunique()
# Out:
# Entity                                                                                215
# Code                                                                                  215
# Day                                                                                   818
# Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)    34718
# Total confirmed cases of COVID-19                                                   87439
# Year                                                                                    1
# Continent                                                                               6
# dtype: int64

# %%
df = df.drop(columns=["Entity", "Code", "Day", "Continent", "Year"])
df
# Out:
#         Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)  \
# 0                                                   0.833
# 1                                                   0.714
# 2                                                   0.000
# 3                                                   0.000
# 4                                                   0.000
# ...                                                   ...
# 162896                                             25.143
# 162897                                             25.000
# 162898                                             35.857
# 162899                                             41.000
# 162900                                             35.143
#
#         Total confirmed cases of COVID-19
# 0                                       5
# 1                                       5
# 2                                       5
# 3                                       5
# ...

# %%
for col in df.columns:
    f, ax = plt.subplots(figsize=(16, 6))
    ax.set_title(col)
    sns.boxenplot(data=df[col], orient="h")
    sns.despine(left=True, bottom=True)

# %%
for col in df.columns:
    f, ax = plt.subplots(figsize=(16, 6))
    ax.set_title(col)
    sns.boxenplot(data=np.log(df[col]), orient="h")
    sns.despine(left=True, bottom=True)
# Out:
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\numpy\lib\function_base.py:4009: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)

# %%
for col in df.columns:
    stats.probplot(np.log(df[col]), dist="norm", plot=pylab)
    pylab.title(col)
    pylab.show()
# Out:
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\numpy\lib\function_base.py:2536: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
raise Exception()
# g = sns.PairGrid(df, diag_sharey=False)
# g.map_upper(sns.scatterplot)
# g.map_lower(sns.kdeplot)
# g.map_diag(sns.kdeplot)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 raise Exception()
#
# Exception:

# %%
sns.scatterplot(data=df,
                y="Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)",
                x="Total confirmed cases of COVID-19")
# Out:
# <AxesSubplot:xlabel='Total confirmed cases of COVID-19', ylabel='Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)'>

# %%
sns.kdeplot(data=df,
            y="Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)",
            x="Total confirmed cases of COVID-19")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 sns.kdeplot(data=df,
#       2             y="Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)",
#       3             x="Total confirmed cases of COVID-19")
#
# File ~\miniconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.kdeplot(data=np.log(df),
            x="Total confirmed cases of COVID-19")
# Out:
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# <AxesSubplot:xlabel='Total confirmed cases of COVID-19', ylabel='Density'>

# %%
sns.kdeplot(data=np.log(df),
            x="Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)")
# Out:
# C:\Users\kolya\miniconda3\envs\tf\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# <AxesSubplot:xlabel='Daily new confirmed cases due to COVID-19 (rolling 7-day average, right-aligned)', ylabel='Density'>
