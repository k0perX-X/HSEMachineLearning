# %%
import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
import scipy.stats as stats
import plotly.express as px
from sklearn import preprocessing

# %%
df = pd.read_csv("DataSet1_3.csv", sep=',')
df["Date"] = df["Date"].astype("datetime64")
df
# Out:
#            Date     Open     High      Low    Close    Volume   Name
# 0    2006-01-03   211.47   218.05   209.32   217.83  13137450  GOOGL
# 1    2006-01-04   222.17   224.70   220.09   222.84  15292353  GOOGL
# 2    2006-01-05   223.22   226.00   220.97   225.85  10815661  GOOGL
# 3    2006-01-06   228.66   235.49   226.85   233.06  17759521  GOOGL
# 4    2006-01-09   233.44   236.94   230.70   233.68  12795837  GOOGL
# ...         ...      ...      ...      ...      ...       ...    ...
# 3014 2017-12-22  1070.00  1071.72  1067.64  1068.86    889446  GOOGL
# 3015 2017-12-26  1068.64  1068.86  1058.64  1065.85    918767  GOOGL
# 3016 2017-12-27  1066.60  1068.27  1058.38  1060.20   1116203  GOOGL
# 3017 2017-12-28  1062.25  1064.84  1053.38  1055.95    994249  GOOGL
# 3018 2017-12-29  1055.49  1058.05  1052.70  1053.40   1180340  GOOGL
#
# [3019 rows x 7 columns]

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# Name              object
# dtype: object

# %%
df.nunique()
# Out:
# Date      3019
# Open      2880
# High      2855
# Low       2875
# Close     2919
# Volume    3019
# Name         1
# dtype: int64

# %%
df = df.drop(columns="Name")

# %%
for col in df.columns.drop("Date"):
    f, ax = plt.subplots(figsize=(16, 6))
    ax.set_title(col)
    sns.boxenplot(data=df[col], orient="h")
    sns.despine(left=True, bottom=True)

# %%
for col in df.columns.drop("Date"):
    f, ax = plt.subplots(figsize=(16, 6))
    ax.set_title(col)
    sns.boxenplot(data=np.log(df[col]), orient="h")
    sns.despine(left=True, bottom=True)

# %%
for col in df.columns.drop("Date"):
    stats.probplot(df[col], dist="norm", plot=pylab)
    pylab.title(col)
    pylab.show()

# %%
for col in df.columns.drop("Date"):
    stats.probplot(np.log(df[col]), dist="norm", plot=pylab)
    pylab.title(col)
    pylab.show()

# %%
np.abs(df.drop(columns="Date").corr()).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f958a_row0_col0, #T_f958a_row0_col1, #T_f958a_row0_col2, #T_f958a_row0_col3, #T_f958a_row1_col0, #T_f958a_row1_col1, #T_f958a_row1_col2, #T_f958a_row1_col3, #T_f958a_row2_col0, #T_f958a_row2_col1, #T_f958a_row2_col2, #T_f958a_row2_col3, #T_f958a_row3_col0, #T_f958a_row3_col1, #T_f958a_row3_col2, #T_f958a_row3_col3, #T_f958a_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f958a_row0_col4, #T_f958a_row3_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f958a_row1_col4, #T_f958a_row4_col0, #T_f958a_row4_col1, #T_f958a_row4_col2, #T_f958a_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f958a_row2_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f958a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f958a_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_f958a_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_f958a_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_f958a_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_f958a_level0_col4" class="col_heading level0 col4" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f958a_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_f958a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f958a_row0_col1" class="data row0 col1" >0.999894</td>
#       <td id="T_f958a_row0_col2" class="data row0 col2" >0.999841</td>
#       <td id="T_f958a_row0_col3" class="data row0 col3" >0.999742</td>
#       <td id="T_f958a_row0_col4" class="data row0 col4" >0.443155</td>
#     </tr>
#     <tr>
#       <th id="T_f958a_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_f958a_row1_col0" class="data row1 col0" >0.999894</td>
#       <td id="T_f958a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f958a_row1_col2" class="data row1 col2" >0.999827</td>
#       <td id="T_f958a_row1_col3" class="data row1 col3" >0.999866</td>
#       <td id="T_f958a_row1_col4" class="data row1 col4" >0.440717</td>
#     </tr>
#     <tr>
#       <th id="T_f958a_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_f958a_row2_col0" class="data row2 col0" >0.999841</td>
#       <td id="T_f958a_row2_col1" class="data row2 col1" >0.999827</td>
#       <td id="T_f958a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f958a_row2_col3" class="data row2 col3" >0.999896</td>
#       <td id="T_f958a_row2_col4" class="data row2 col4" >0.447781</td>
#     </tr>
#     <tr>
#       <th id="T_f958a_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_f958a_row3_col0" class="data row3 col0" >0.999742</td>
#       <td id="T_f958a_row3_col1" class="data row3 col1" >0.999866</td>
#       <td id="T_f958a_row3_col2" class="data row3 col2" >0.999896</td>
#       <td id="T_f958a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f958a_row3_col4" class="data row3 col4" >0.444590</td>
#     </tr>
#     <tr>
#       <th id="T_f958a_level0_row4" class="row_heading level0 row4" >Volume</th>
#       <td id="T_f958a_row4_col0" class="data row4 col0" >0.443155</td>
#       <td id="T_f958a_row4_col1" class="data row4 col1" >0.440717</td>
#       <td id="T_f958a_row4_col2" class="data row4 col2" >0.447781</td>
#       <td id="T_f958a_row4_col3" class="data row4 col3" >0.444590</td>
#       <td id="T_f958a_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.abs(np.log(df.drop(columns="Date")).corr()).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_889cf_row0_col0, #T_889cf_row0_col1, #T_889cf_row0_col2, #T_889cf_row0_col3, #T_889cf_row1_col0, #T_889cf_row1_col1, #T_889cf_row1_col2, #T_889cf_row1_col3, #T_889cf_row2_col0, #T_889cf_row2_col1, #T_889cf_row2_col2, #T_889cf_row2_col3, #T_889cf_row3_col0, #T_889cf_row3_col1, #T_889cf_row3_col2, #T_889cf_row3_col3, #T_889cf_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_889cf_row0_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_889cf_row1_col4, #T_889cf_row4_col0, #T_889cf_row4_col1, #T_889cf_row4_col2, #T_889cf_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_889cf_row2_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_889cf_row3_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_889cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_889cf_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_889cf_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_889cf_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_889cf_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_889cf_level0_col4" class="col_heading level0 col4" >Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_889cf_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_889cf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_889cf_row0_col1" class="data row0 col1" >0.999831</td>
#       <td id="T_889cf_row0_col2" class="data row0 col2" >0.999768</td>
#       <td id="T_889cf_row0_col3" class="data row0 col3" >0.999614</td>
#       <td id="T_889cf_row0_col4" class="data row0 col4" >0.651479</td>
#     </tr>
#     <tr>
#       <th id="T_889cf_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_889cf_row1_col0" class="data row1 col0" >0.999831</td>
#       <td id="T_889cf_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_889cf_row1_col2" class="data row1 col2" >0.999711</td>
#       <td id="T_889cf_row1_col3" class="data row1 col3" >0.999802</td>
#       <td id="T_889cf_row1_col4" class="data row1 col4" >0.647506</td>
#     </tr>
#     <tr>
#       <th id="T_889cf_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_889cf_row2_col0" class="data row2 col0" >0.999768</td>
#       <td id="T_889cf_row2_col1" class="data row2 col1" >0.999711</td>
#       <td id="T_889cf_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_889cf_row2_col3" class="data row2 col3" >0.999820</td>
#       <td id="T_889cf_row2_col4" class="data row2 col4" >0.657857</td>
#     </tr>
#     <tr>
#       <th id="T_889cf_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_889cf_row3_col0" class="data row3 col0" >0.999614</td>
#       <td id="T_889cf_row3_col1" class="data row3 col1" >0.999802</td>
#       <td id="T_889cf_row3_col2" class="data row3 col2" >0.999820</td>
#       <td id="T_889cf_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_889cf_row3_col4" class="data row3 col4" >0.653019</td>
#     </tr>
#     <tr>
#       <th id="T_889cf_level0_row4" class="row_heading level0 row4" >Volume</th>
#       <td id="T_889cf_row4_col0" class="data row4 col0" >0.651479</td>
#       <td id="T_889cf_row4_col1" class="data row4 col1" >0.647506</td>
#       <td id="T_889cf_row4_col2" class="data row4 col2" >0.657857</td>
#       <td id="T_889cf_row4_col3" class="data row4 col3" >0.653019</td>
#       <td id="T_889cf_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
g = sns.PairGrid(df, diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)
